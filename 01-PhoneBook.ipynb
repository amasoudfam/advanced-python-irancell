# %% [markdown]
# > **About this Notebook**
# > This notebook is part of the *Advanced Python* video series created in collaboration with **Irancell Academy**.
# > 🎥 Videos and full article: [الگوریتمستان - پایتون پیشرفته آکادمی ایرانسل](https://www.amasoudfam.ir/blog/%D9%88%DB%8C%D8%AF%D8%A6%D9%88-%D9%BE%D8%A7%DB%8C%D8%AA%D9%88%D9%86-%D9%BE%DB%8C%D8%B4%D8%B1%D9%81%D8%AA%D9%87-%D8%A7%DB%8C%D8%B1%D8%A7%D9%86%D8%B3%D9%84/)

# %%
print('Hello Python!')
# Out:
# Hello Python!

# %%
def displayMenu():
    while True:
        print('Welcome!')
        print('------------------')
        print('1) Add contact')
        print('2) Edit contact')
        print('3) Delete contact')
        print('4) Search contact')
        print('9) Quit')
        print('-------------------')
        print('Please enter your choice:')
        cmd = input()
        if cmd in ['1', '2', '3', '4', '9']:
            return cmd
        print('Invalid input. Please try again.')

while True:
        cmd = displayMenu()
        if cmd == '9':
            print('Bye!')
            break
# Out:
# Welcome!
# ------------------
# 1) Add contact
# 2) Edit contact
# 3) Delete contact
# 4) Search contact
# 9) Quit
# -------------------
# Please enter your choice:
#  1
# Welcome!
# ------------------
# 1) Add contact
# 2) Edit contact
# 3) Delete contact
# 4) Search contact
# 9) Quit
# -------------------
# Please enter your choice:
#  9
# Bye!

# %%
def displayMenu():
    while True:
        print('Welcome!')
        print('------------------')
        print('1) Add contact')
        print('2) Edit contact')
        print('3) Delete contact')
        print('4) Search contact')
        print('9) Quit')
        print('-------------------')
        print('Please enter your choice:')
        cmd = input()
        if cmd in ['1', '2', '3', '4', '9']:
            return cmd
        print('Invalid input. Please try again.')
contact_list = dict()
while True:
    cmd = displayMenu()
    if cmd == '1':
        name = input('Please enter name:')
        if name in contact_list:
            print('This name already exists!')
            continue
        number = input('Please enter phone number:')
        contact_list[name] = number
        print('Done!')
    if cmd == '9':
        print('Bye!')
        break
# Out:
# Welcome!
# ------------------
# 1) Add contact
# 2) Edit contact
# 3) Delete contact
# 4) Search contact
# 9) Quit
# -------------------
# Please enter your choice:
#  1
# Please enter name: Masoud
# Please enter phone number: 1234567
# Done!
# Welcome!
# ------------------
# 1) Add contact
# 2) Edit contact
# 3) Delete contact
# 4) Search contact
# 9) Quit
# -------------------
# Please enter your choice:
#  4
# Welcome!
# ------------------
# 1) Add contact
# 2) Edit contact
# 3) Delete contact
# 4) Search contact
# 9) Quit
# -------------------
# Please enter your choice:
#  9
# Bye!

# %%
def displayMenu():
    while True:
        print('Welcome!')
        print('------------------')
        print('1) Add contact')
        print('2) Edit contact')
        print('3) Delete contact')
        print('4) Search contact')
        print('9) Quit')
        print('-------------------')
        print('Please enter your choice:')
        cmd = input()
        if cmd in ['1', '2', '3', '4', '9']:
            return cmd
        print('Invalid input. Please try again.')
contact_list = dict()
while True:
    cmd = displayMenu()
    if cmd == '1':
        name = input('Please enter name:')
        if name in contact_list:
            print('This name already exists!')
            continue
        number = input('Please enter phone number:')
        contact_list[name] = number
        print('Done!')
    if cmd == '3':
        name = input('Please enter name:')
        if name not in contact_list:
            print('This name does not exit!')
            continue
        del contact_list[name]
        print('Done!')
    if cmd == '4':
        name = input('Please enter name:')
        if name not in contact_list:
            print('This name does not exit!')
            continue
        print(f'{name}: {contact_list[name]}')
    if cmd == '9':
        print('Bye!')
        break
# Out:
# Welcome!
# ------------------
# 1) Add contact
# 2) Edit contact
# 3) Delete contact
# 4) Search contact
# 9) Quit
# -------------------
# Please enter your choice:
#  1
# Please enter name: Masoud Aghdasifam
# Please enter phone number: 7654321
# Done!
# Welcome!
# ------------------
# 1) Add contact
# 2) Edit contact
# 3) Delete contact
# 4) Search contact
# 9) Quit
# -------------------
# Please enter your choice:
#  4
# Please enter name: Masoud
# This name does not exit!
# Welcome!
# ------------------
# 1) Add contact
# 2) Edit contact
# 3) Delete contact
# 4) Search contact
# 9) Quit
# -------------------
# Please enter your choice:
#  4
# Please enter name: Masoud Aghdasifam
# Masoud Aghdasifam: 7654321
# Welcome!
# ------------------
# 1) Add contact
# 2) Edit contact
# 3) Delete contact
# 4) Search contact
# 9) Quit
# -------------------
# Please enter your choice:
#  9
# Bye!

# %%
def displayMenu():
    while True:
        print('Welcome!')
        print('------------------')
        print('1) Add contact')
        print('2) Edit contact')
        print('3) Delete contact')
        print('4) Search contact')
        print('9) Quit')
        print('-------------------')
        print('Please enter your choice:')
        cmd = input()
        if cmd in ['1', '2', '3', '4', '9']:
            return cmd
        print('Invalid input. Please try again.')

def save2file(contact_list):
    try:
        with open('list.csv', 'w') as f:
            for name, number in contact_list.items():
                f.write(f'{name}, {number},\n')
    except:
        print('Failed to save data')

def loadFile():
    result = dict()
    try:
        with open('list.csv', 'r') as f:
            for line in f:
                name, number, *_ = line.split(',')
                result[name] = number
        return result
    except Exception as e:
        print('Failed to load data')
        print(e)
        return dict()

contact_list = loadFile()
while True:
    cmd = displayMenu()
    if cmd == '1':
        name = input('Please enter name:')
        if name in contact_list:
            print('This name already exists!')
            continue
        number = input('Please enter phone number:')
        contact_list[name] = number
        save2file(contact_list)
        print('Done!')
    if cmd == '3':
        name = input('Please enter name:')
        if name not in contact_list:
            print('This name does not exit!')
            continue
        del contact_list[name]
        save2file(contact_list)
        print('Done!')
    if cmd == '4':
        name = input('Please enter name:')
        if name not in contact_list:
            print('This name does not exit!')
            continue
        print(f'{name}: {contact_list[name]}')
    if cmd == '9':
        print('Bye!')
        break
# Out:
# Failed to load data
# [Errno 2] No such file or directory: 'list.csv'
# Welcome!
# ------------------
# 1) Add contact
# 2) Edit contact
# 3) Delete contact
# 4) Search contact
# 9) Quit
# -------------------
# Please enter your choice:
#  1
# Please enter name: Masoud
# Please enter phone number: 1234567
# Done!
# Welcome!
# ------------------
# 1) Add contact
# 2) Edit contact
# 3) Delete contact
# 4) Search contact
# 9) Quit
# -------------------
# Please enter your choice:
#  4
# Please enter name: Masoud
# Masoud: 1234567
# Welcome!
# ------------------
# 1) Add contact
# 2) Edit contact
# 3) Delete contact
# 4) Search contact
# 9) Quit
# -------------------
# Please enter your choice:
#  9
# Bye!

# %%
def displayMenu():
    while True:
        print('Welcome!')
        print('------------------')
        print('1) Add contact')
        print('2) Edit contact')
        print('3) Delete contact')
        print('4) Search contact')
        print('9) Quit')
        print('-------------------')
        print('Please enter your choice:')
        cmd = input()
        if cmd in ['1', '2', '3', '4', '9']:
            return cmd
        print('Invalid input. Please try again.')

def save2file(contact_list):
    try:
        with open('list.csv', 'w') as f:
            for name, number in contact_list.items():
                f.write(f'{name}, {number},\n')
    except:
        print('Failed to save data')

def loadFile():
    result = dict()
    try:
        with open('list.csv', 'r') as f:
            for line in f:
                name, number, *_ = line.split(',')
                result[name] = number
        return result
    except Exception as e:
        print('Failed to load data')
        print(e)
        return dict()

contact_list = loadFile()
while True:
    cmd = displayMenu()
    if cmd == '1':
        name = input('Please enter name:')
        if name in contact_list:
            print('This name already exists!')
            continue
        number = input('Please enter phone number:')
        contact_list[name] = number
        save2file(contact_list)
        print('Done!')
    if cmd == '3':
        name = input('Please enter name:')
        if name not in contact_list:
            print('This name does not exit!')
            continue
        del contact_list[name]
        save2file(contact_list)
        print('Done!')
    if cmd == '4':
        name = input('Please enter name:')
        if name not in contact_list:
            print('This name does not exit!')
            continue
        print(f'{name}: {contact_list[name]}')
    if cmd == '9':
        print('Bye!')
        break
# Out:
# Welcome!
# ------------------
# 1) Add contact
# 2) Edit contact
# 3) Delete contact
# 4) Search contact
# 9) Quit
# -------------------
# Please enter your choice:
#  4
# Please enter name: Masoud
# Masoud:  1234567
# Welcome!
# ------------------
# 1) Add contact
# 2) Edit contact
# 3) Delete contact
# 4) Search contact
# 9) Quit
# -------------------
# Please enter your choice:
#  9
# Bye!
